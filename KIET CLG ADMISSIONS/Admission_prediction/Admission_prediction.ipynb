# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the dataset
data = pd.read_csv("Admissiondataset@1234.csv")
data.head()
# Out:
#                         NAME  ADMISSION             DISTRICT  CATEGORY  \
# 0                 Bhaghavan           0  Alluri Sitaramaraju         1
# 1  Raghupathi Venkaiah Naidu          0  Alluri Sitaramaraju         1
# 2       Gopichand Lagadapati          0  Alluri Sitaramaraju         1
# 3                      Rohit          0  Alluri Sitaramaraju         1
# 4                     Devika          0  Alluri Sitaramaraju         1
#
#   COLLEGE  YEAR
# 0    KIET  2022
# 1    KIET  2022
# 2    KIET  2022
# 3    KIET  2022
# 4    KIET  2022

# %%
data.shape
# Out:
# (8999, 6)

# %%
data['ADMISSION'] = data['ADMISSION'].astype(float)

# %%
data['CATEGORY'] = data['CATEGORY'].astype(float)

# %%
data['YEAR'] = data['YEAR'].astype(float)

# %%
data.describe
# Out:
# <bound method NDFrame.describe of                            NAME  ADMISSION             DISTRICT  CATEGORY  \
# 0                    Bhaghavan         0.0  Alluri Sitaramaraju       1.0
# 1     Raghupathi Venkaiah Naidu        0.0  Alluri Sitaramaraju       1.0
# 2          Gopichand Lagadapati        0.0  Alluri Sitaramaraju       1.0
# 3                         Rohit        0.0  Alluri Sitaramaraju       1.0
# 4                        Devika        0.0  Alluri Sitaramaraju       1.0
# ...                         ...        ...                  ...       ...
# 8994                 Jaya Prada        1.0           YSR Kadapa       1.0
# 8995            Devi Sri Prasad        1.0           YSR Kadapa       1.0
# 8996     Bhanumathi Ramakrishna        1.0           YSR Kadapa       1.0
# 8997                    Prabhas        1.0           YSR Kadapa       1.0
# 8998                    akilash        1.0           YSR Kadapa       1.0
#
#      COLLEGE    YEAR
# 0       KIET  2022.0
# ...

# %%
data.isnull().sum()
# Out:
# NAME         0
# ADMISSION    0
# DISTRICT     0
# CATEGORY     0
# COLLEGE      0
# YEAR         0
# dtype: int64

# %%
#Data clean: handle null values
data = data.dropna()

# %%
data.COLLEGE.unique()
# Out:
# array(['KIET', 'KIEW', 'KIEK'], dtype=object)

# %%
data = data.drop('NAME',axis=1)

# %%
data.DISTRICT.unique()
# Out:
# array(['Alluri Sitaramaraju', 'Anakapalli', 'Anantapur', 'Annamayya',
#        'Bapatla', 'Chittoor', 'Dr. B. R. Ambedkar Konaseema',
#        'East Godavari', 'Eluru', 'Guntur', 'Kakinada', 'Krishna',
#        'Kurnool', 'Nandyala', 'NTR District', 'Palnadu',
#        'Parvathipuram Manyam', 'Prakasam ', 'SPS Nellore',
#        'Sri Sathya Sai', 'Srikakulam', 'Tirupati', 'Visakhapatnam',
#        'Vizianagaram', 'West Godavari', 'YSR Kadapa'], dtype=object)

# %%
len(data.DISTRICT.unique())
# Out:
# 26

# %%
DISTRICT_count = data.groupby('DISTRICT').size().sort_values(ascending=False)
DISTRICT_count
# Out:
# DISTRICT
# East Godavari                   924
# Kakinada                        905
# Eluru                           681
# West Godavari                   531
# Vizianagaram                    506
# Srikakulam                      449
# Parvathipuram Manyam            391
# Annamayya                       352
# Guntur                          348
# Visakhapatnam                   311
# Dr. B. R. Ambedkar Konaseema    288
# Prakasam                        287
# Krishna                         269
# SPS Nellore                     247
# YSR Kadapa                      245
# Anakapalli                      239
# Tirupati                        221
# Anantapur                       216
# NTR District                    212
# Palnadu                         212
# Sri Sathya Sai                  210
# Nandyala                        208
# Kurnool                         208
# Alluri Sitaramaraju             205
# Chittoor                        167
# Bapatla                         167
# ...

# %%
len(DISTRICT_count[DISTRICT_count<=10])
# Out:
# 0

# %%
data.drop_duplicates(subset=['DISTRICT'], inplace=True)

# %%
data.DISTRICT.unique()
# Out:
# array(['Alluri Sitaramaraju', 'Anakapalli', 'Anantapur', 'Annamayya',
#        'Bapatla', 'Chittoor', 'Dr. B. R. Ambedkar Konaseema',
#        'East Godavari', 'Eluru', 'Guntur', 'Kakinada', 'Krishna',
#        'Kurnool', 'Nandyala', 'NTR District', 'Palnadu',
#        'Parvathipuram Manyam', 'Prakasam ', 'SPS Nellore',
#        'Sri Sathya Sai', 'Srikakulam', 'Tirupati', 'Visakhapatnam',
#        'Vizianagaram', 'West Godavari', 'YSR Kadapa'], dtype=object)

# %%
len(data.DISTRICT.unique())
# Out:
# 26

# %%
DISTRICT_count = data.groupby('DISTRICT').size().sort_values(ascending=False)
DISTRICT_count
# Out:
# DISTRICT
# Alluri Sitaramaraju             1
# Anakapalli                      1
# West Godavari                   1
# Vizianagaram                    1
# Visakhapatnam                   1
# Tirupati                        1
# Srikakulam                      1
# Sri Sathya Sai                  1
# SPS Nellore                     1
# Prakasam                        1
# Parvathipuram Manyam            1
# Palnadu                         1
# Nandyala                        1
# NTR District                    1
# Kurnool                         1
# Krishna                         1
# Kakinada                        1
# Guntur                          1
# Eluru                           1
# East Godavari                   1
# Dr. B. R. Ambedkar Konaseema    1
# Chittoor                        1
# Bapatla                         1
# Annamayya                       1
# Anantapur                       1
# YSR Kadapa                      1
# dtype: int64

# %%
len(DISTRICT_count[DISTRICT_count<=1])
# Out:
# 26

# %%
DISTRICT_less_1 = DISTRICT_count[DISTRICT_count<=1]

# %%
# data.DISTRICT = data.DISTRICT.apply(lambda x: 'other' if x in DISTRICT_less_1 else x)

# %%
len(data.DISTRICT.unique())
# Out:
# 26

# %%
data.head()
# Out:
#       ADMISSION             DISTRICT  CATEGORY COLLEGE    YEAR
# 0           0.0  Alluri Sitaramaraju       1.0    KIET  2022.0
# 205         0.0           Anakapalli       2.0    KIET  2023.0
# 444         0.0            Anantapur       2.0    KIET  2022.0
# 660         0.0            Annamayya       2.0    KIET  2023.0
# 1012        0.0              Bapatla       1.0    KIET  2023.0

# %%
dummies = pd.get_dummies(data.DISTRICT)
DISTRICT_cat = pd.get_dummies(data.DISTRICT)
dummies.head()
# Out:
#       Alluri Sitaramaraju  Anakapalli  Anantapur  Annamayya  Bapatla  \
# 0                       1           0          0          0        0
# 205                     0           1          0          0        0
# 444                     0           0          1          0        0
# 660                     0           0          0          1        0
# 1012                    0           0          0          0        1
#
#       Chittoor  Dr. B. R. Ambedkar Konaseema  East Godavari  Eluru  Guntur  \
# 0            0                             0              0      0       0
# 205          0                             0              0      0       0
# 444          0                             0              0      0       0
# 660          0                             0              0      0       0
# 1012         0                             0              0      0       0
#
#       ...  Parvathipuram Manyam  Prakasam   SPS Nellore  Sri Sathya Sai  \
# ...

# %%
data = pd.concat([data,dummies.drop('Alluri Sitaramaraju',axis='columns')],axis='columns')
data.head()
# Out:
#       ADMISSION             DISTRICT  CATEGORY COLLEGE    YEAR  Anakapalli  \
# 0           0.0  Alluri Sitaramaraju       1.0    KIET  2022.0           0
# 205         0.0           Anakapalli       2.0    KIET  2023.0           1
# 444         0.0            Anantapur       2.0    KIET  2022.0           0
# 660         0.0            Annamayya       2.0    KIET  2023.0           0
# 1012        0.0              Bapatla       1.0    KIET  2023.0           0
#
#       Anantapur  Annamayya  Bapatla  Chittoor  ...  Parvathipuram Manyam  \
# 0             0          0        0         0  ...                     0
# 205           0          0        0         0  ...                     0
# 444           1          0        0         0  ...                     0
# 660           0          1        0         0  ...                     0
# 1012          0          0        1         0  ...                     0
#
#       Prakasam   SPS Nellore  Sri Sathya Sai  Srikakulam  Tirupati  \
# ...

# %%
len(data.DISTRICT.unique())
# Out:
# 26

# %%
dummies = pd.get_dummies(data.COLLEGE)
dummies.head()
# Out:
#       KIEK  KIET  KIEW
# 0        0     1     0
# 205      0     1     0
# 444      0     1     0
# 660      0     1     0
# 1012     0     1     0

# %%
data = pd.concat([data,dummies],axis='columns')
data.head()
# Out:
#       ADMISSION             DISTRICT  CATEGORY COLLEGE    YEAR  Anakapalli  \
# 0           0.0  Alluri Sitaramaraju       1.0    KIET  2022.0           0
# 205         0.0           Anakapalli       2.0    KIET  2023.0           1
# 444         0.0            Anantapur       2.0    KIET  2022.0           0
# 660         0.0            Annamayya       2.0    KIET  2023.0           0
# 1012        0.0              Bapatla       1.0    KIET  2023.0           0
#
#       Anantapur  Annamayya  Bapatla  Chittoor  ...  Sri Sathya Sai  \
# 0             0          0        0         0  ...               0
# 205           0          0        0         0  ...               0
# 444           1          0        0         0  ...               0
# 660           0          1        0         0  ...               0
# 1012          0          0        1         0  ...               0
#
#       Srikakulam  Tirupati  Visakhapatnam  Vizianagaram  West Godavari  \
# ...

# %%
data = pd.concat([data,dummies],axis='columns')
data.head()
# Out:
#       ADMISSION             DISTRICT  CATEGORY COLLEGE    YEAR  Anakapalli  \
# 0           0.0  Alluri Sitaramaraju       1.0    KIET  2022.0           0
# 205         0.0           Anakapalli       2.0    KIET  2023.0           1
# 444         0.0            Anantapur       2.0    KIET  2022.0           0
# 660         0.0            Annamayya       2.0    KIET  2023.0           0
# 1012        0.0              Bapatla       1.0    KIET  2023.0           0
#
#       Anantapur  Annamayya  Bapatla  Chittoor  ...  Visakhapatnam  \
# 0             0          0        0         0  ...              0
# 205           0          0        0         0  ...              0
# 444           1          0        0         0  ...              0
# 660           0          1        0         0  ...              0
# 1012          0          0        1         0  ...              0
#
#       Vizianagaram  West Godavari  YSR Kadapa  KIEK  KIET  KIEW  KIEK  KIET  \
# ...

# %%
data = data.drop(['DISTRICT','COLLEGE'] , axis=1)

# %%
data.head()
# Out:
#       ADMISSION  CATEGORY    YEAR  Anakapalli  Anantapur  Annamayya  Bapatla  \
# 0           0.0       1.0  2022.0           0          0          0        0
# 205         0.0       2.0  2023.0           1          0          0        0
# 444         0.0       2.0  2022.0           0          1          0        0
# 660         0.0       2.0  2023.0           0          0          1        0
# 1012        0.0       1.0  2023.0           0          0          0        1
#
#       Chittoor  Dr. B. R. Ambedkar Konaseema  East Godavari  ...  \
# 0            0                             0              0  ...
# 205          0                             0              0  ...
# 444          0                             0              0  ...
# 660          0                             0              0  ...
# 1012         0                             0              0  ...
#
#       Visakhapatnam  Vizianagaram  West Godavari  YSR Kadapa  KIEK  KIET  \
# ...

# %%
X = data.drop(['ADMISSION'], axis=1)
y=data['ADMISSION']

# %%
#split data into train-test split
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
regressor = cross_val_score(LinearRegression(), X, y, cv=cv)
regressor
# Out:
# array([ 0. ,  0. , -0.2,  0. ,  0. ])

# %%
np.average(regressor)
# Out:
# -0.039999999999999945

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(X,y,test_size=0.3)

# %%
model = LinearRegression()
model.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn import metrics
print(metrics.mean_absolute_error(y_test,y_pred))
print(metrics.mean_squared_error(y_test,y_pred))
print(np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# 0.023646808149828002
# 0.0009882932409697458
# 0.03143713156396025

# %%
data.head()
# Out:
#       ADMISSION  CATEGORY    YEAR  Anakapalli  Anantapur  Annamayya  Bapatla  \
# 0           0.0       1.0  2022.0           0          0          0        0
# 205         0.0       2.0  2023.0           1          0          0        0
# 444         0.0       2.0  2022.0           0          1          0        0
# 660         0.0       2.0  2023.0           0          0          1        0
# 1012        0.0       1.0  2023.0           0          0          0        1
#
#       Chittoor  Dr. B. R. Ambedkar Konaseema  East Godavari  ...  \
# 0            0                             0              0  ...
# 205          0                             0              0  ...
# 444          0                             0              0  ...
# 660          0                             0              0  ...
# 1012         0                             0              0  ...
#
#       Visakhapatnam  Vizianagaram  West Godavari  YSR Kadapa  KIEK  KIET  \
# ...

# %%
#save the model
import pickle
with open('model.pkl', 'wb') as fh:
   pickle.dump(model, fh)

# %%
cat = data.drop(['ADMISSION'] , axis=1)
index_dict = dict(zip(cat.columns,range(cat.shape[1])))
with open('cat', 'wb') as fid:
    pickle.dump(index_dict, fid,2)

# %%
DISTRICT_list = list(zip(DISTRICT_cat.columns,range(cat.shape[1])))

# %%
with open('DISTRICT_cat', 'wb') as fid:
    pickle.dump(DISTRICT_list, fid,2)

# %%
def predict(DISTRICT,COLLEGE,CATEGORY,YEAR):
    output = np.zeros(33)
    output[0] = YEAR
    output[1] = CATEGORY

    result_DISTRICT = DISTRICT
    if result_DISTRICT not in DISTRICT_cat:
        output[28] = 1
    else:
        output[index_dict[str(DISTRICT)]] = 1
    
    return model.predict([output])[0]

# %%
predict('Visakhapatnam','KIEW',2,2023)
# Out:
# C:\Users\harshini\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 72.81106706265383

# %%
predict('Palnadu','KIEW',1,2023)
# Out:
# C:\Users\harshini\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 72.81992366058968
